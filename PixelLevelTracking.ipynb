# %%
import os
import sys
import math
import glob
import time
import json
import base64
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import cv2
from PIL import Image, ImageOps

# %%
vid_file_path = "/home/anagara8/Documents/Autoencoder/Videos/video.mp4"

# %%
cap=cv2.VideoCapture(vid_file_path)
ret,frame=cap.read()

plt.imshow(frame)

# %%
frame[350][180]
# Out:
# array([118, 118, 118], dtype=uint8)

# %%
hsv=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
hsv[450][40]
# Out:
# array([  0,   0, 204], dtype=uint8)

# %%
l_b=np.array([0,0,95])# lower hsv bound for red
u_b=np.array([0,0,180])# upper hsv bound to red

while ret==True:
    ret,frame=cap.read()

    hsv=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
    mask=cv2.inRange(hsv,l_b,u_b)

    contours,_= cv2.findContours(mask,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    plt.imshow(mask)
    max_contour = contours[1]
    
    print("Contours:", len(contours))
#     for contour in contours:
#         print(contour)
        
    for contour in contours:
        if cv2.contourArea(contour)>cv2.contourArea(max_contour):

            max_contour=contour
            approx = cv2.approxPolyDP(contour, 0.01*cv2.arcLength(contour,True),True)
            x,y,w,h = cv2.boundingRect(approx)
            cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),4)

    contour = max_contour
    approx = cv2.approxPolyDP(contour, 0.01*cv2.arcLength(contour,True),True)
    x,y,w,h = cv2.boundingRect(approx)
    cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),4)

    cv2.imshow("Video",frame)

    cv2.imshow("Mask",mask)


    key=cv2.waitKey(1)
    if key==ord('q'):
        break
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Contours: 518
# Contours: 551
# Contours: 542
# Contours: 695
# Contours: 657
# Contours: 622
# Contours: 609
# Contours: 610
# Contours: 770
# Contours: 701
# Contours: 646
# Contours: 749
# Contours: 651
# Contours: 643
# Contours: 705
# Contours: 649
# QObject::moveToThread: Current thread (0x55fe42948e60) is not the object's thread (0x55fe431bc7d0).
# Cannot move to target thread (0x55fe42948e60)
#
# QObject::moveToThread: Current thread (0x55fe42948e60) is not the object's thread (0x55fe431bc7d0).
# Cannot move to target thread (0x55fe42948e60)
#
# QObject::moveToThread: Current thread (0x55fe42948e60) is not the object's thread (0x55fe431bc7d0).
# Cannot move to target thread (0x55fe42948e60)
#
# QObject::moveToThread: Current thread (0x55fe42948e60) is not the object's thread (0x55fe431bc7d0).
# Cannot move to target thread (0x55fe42948e60)
#
# QObject::moveToThread: Current thread (0x55fe42948e60) is not the object's thread (0x55fe431bc7d0).
# ...
